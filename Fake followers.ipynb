# %%
import numpy as np
import pandas as pd
import itertools

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
train_data
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.27               0                  0.00
# 1              1                  0.00               2                  0.00
# 2              1                  0.10               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.00               2                  0.00
# ..           ...                   ...             ...                   ...
# 571            1                  0.55               1                  0.44
# 572            1                  0.38               1                  0.33
# 573            1                  0.57               2                  0.00
# 574            1                  0.57               1                  0.00
# 575            1                  0.27               1                  0.00
#
# ...

# %%
test_data
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.33               1                  0.33
# 1              1                  0.00               5                  0.00
# 2              1                  0.00               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.50               1                  0.00
# ..           ...                   ...             ...                   ...
# 115            1                  0.29               1                  0.00
# 116            1                  0.40               1                  0.00
# 117            1                  0.00               2                  0.00
# 118            0                  0.17               1                  0.00
# 119            1                  0.44               1                  0.00
#
# ...

# %%
x_train = train_data.drop(columns='fake')
x_train
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.27               0                  0.00
# 1              1                  0.00               2                  0.00
# 2              1                  0.10               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.00               2                  0.00
# ..           ...                   ...             ...                   ...
# 571            1                  0.55               1                  0.44
# 572            1                  0.38               1                  0.33
# 573            1                  0.57               2                  0.00
# 574            1                  0.57               1                  0.00
# 575            1                  0.27               1                  0.00
#
# ...

# %%
y_train = train_data.iloc[:,-1]
y_train
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 571    1
# 572    1
# 573    1
# 574    1
# 575    1
# Name: fake, Length: 576, dtype: int64

# %%
x_test = test_data.drop(columns='fake')
x_test
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.33               1                  0.33
# 1              1                  0.00               5                  0.00
# 2              1                  0.00               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.50               1                  0.00
# ..           ...                   ...             ...                   ...
# 115            1                  0.29               1                  0.00
# 116            1                  0.40               1                  0.00
# 117            1                  0.00               2                  0.00
# 118            0                  0.17               1                  0.00
# 119            1                  0.44               1                  0.00
#
# ...

# %%
y_test = test_data['fake']

# %%
y_test
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 115    1
# 116    1
# 117    1
# 118    1
# 119    1
# Name: fake, Length: 120, dtype: int64

# %%
x_data ,y_data = x_train,y_train

# %%
x_data
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.27               0                  0.00
# 1              1                  0.00               2                  0.00
# 2              1                  0.10               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.00               2                  0.00
# ..           ...                   ...             ...                   ...
# 571            1                  0.55               1                  0.44
# 572            1                  0.38               1                  0.33
# 573            1                  0.57               2                  0.00
# 574            1                  0.57               1                  0.00
# 575            1                  0.27               1                  0.00
#
# ...

# %%
y_data
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 571    1
# 572    1
# 573    1
# 574    1
# 575    1
# Name: fake, Length: 576, dtype: int64

# %%
x_data.isnull().sum()
# Out:
# profile pic             0
# nums/length username    0
# fullname words          0
# nums/length fullname    0
# name==username          0
# description length      0
# external URL            0
# private                 0
# #posts                  0
# #followers              0
# #follows                0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_data,y_data)

# %%
x_train
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 149            1                  0.08               2                   0.0
# 327            0                  0.33               1                   0.0
# 140            1                  0.00               0                   0.0
# 141            1                  0.29               1                   0.0
# 506            0                  0.57               2                   0.0
# ..           ...                   ...             ...                   ...
# 115            1                  0.10               1                   0.1
# 407            0                  0.42               1                   0.0
# 113            1                  0.44               1                   0.0
# 355            1                  0.18               1                   0.0
# 150            1                  0.00               2                   0.0
#
# ...

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %% [markdown]
# ###  Support Vector Machine

# %%
from sklearn.svm import SVC
Svc = SVC()
Svc.fit(x_train,y_train)
y_pred = Svc.predict(x_test)
svc_score = accuracy_score(y_pred,y_test)
print(f'Accuracy= {round(svc_score*100,2)}%')
# Out:
# Accuracy= 49.31%

# %% [markdown]
# ### Logisitic Regression

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(x_train,y_train)
log_pred = log_reg.predict(x_test)
log_score = accuracy_score(log_pred,y_test)
print(f'Accuracy = {round(log_score*100,2)}%')
# Out:
# Accuracy = 93.06%

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier()
rf_clf.fit(x_train,y_train)
rf_pred = rf_clf.predict(x_test)
rf_score = accuracy_score(rf_pred,y_test)
print(f'Accuracy = {round(rf_score*100,2)}%')
# Out:
# Accuracy = 91.67%

# %% [markdown]
# ### Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb_clf = GradientBoostingClassifier()
gb_clf.fit(x_train,y_train)
gb_pred = gb_clf.predict(x_test)
gb_score = accuracy_score(gb_pred,y_test)
print(f'Accuracy= {round(gb_score*100,2)}%')
# Out:
# Accuracy= 90.28%

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(x_train,y_train)
nb_pred = nb.predict(x_test)
nb_score = accuracy_score(nb_pred,y_test)
print(f'Accuracy= {round(nb_score*100,2)}%')
# Out:
# Accuracy= 69.44%

# %% [markdown]
# ### Average Accuracy

# %%
avg_acc = (svc_score+log_score+rf_score+gb_score+nb_score)/5
print(f'Average Accuracy = {round(avg_acc*100,2)}%')
# Out:
# Average Accuracy = 78.75%

# %% [markdown]
# ### Confusion Matrix

# %%
cm = confusion_matrix(y_test,nb_pred)
print(cm)
# Out:
# [[31 42]
#  [ 2 69]]
